# %% [markdown]
# # Data Stuctures
#  # List

# %%
l = [1,2,3,4,5,6,7,8]
l[1:7]  # Slice Method
# Out:
# [2, 3, 4, 5, 6, 7]

# %%
l[::-1]
# Out:
# [8, 7, 6, 5, 4, 3, 2, 1]

# %%
l[-4:-6:-1]
# Out:
# [5, 4]

# %%
l.index(8)
# Out:
# 7

# %%
l
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
l[7:3:-1]
# Out:
# [8, 7, 6, 5]

# %%
l = [1,2,3,4,5,6,7,8]
l[1:4] = l[1:4][::-1] 
l
# Out:
# [1, 4, 3, 2, 5, 6, 7, 8]

# %%
l[::-1]
# Out:
# [8, 7, 6, 5, 2, 3, 4, 1]

# %%
l.index(4)
# Out:
# 1

# %%
l[4:0] = l[4:0][::-1]
l
# Out:
# [3, 4, 1, 2, 5, 6, 7, 8]

# %%
b = [1,2,3,4,5,6]
b[::-1]
# Out:
# [6, 5, 4, 3, 2, 1]

# %%
l = ['hi','hello','good','great','fit']
l[4] = 'hit'   # Updateing the list
print(l)
# Out:
# ['hi', 'hello', 'good', 'great', 'hit']

# %%
l.append([1,2,3,4]) # add the elements as it is.
print(l)
# Out:
# ['hi', 'hello', 'good', 'great', 'hit', 'fight', ['fight', 'Right'], [1, 2, 3, 4]]

# %%
l.extend([1,2])
print(l)
# Out:
# ['hi', 'hello', 'good', 'great', 'hit', 'fight', ['fight', 'Right'], [1, 2, 3, 4], 1, 2]

# %%
a = [10,20,30,40]
a.extend([1,2,3,4]) # add the element saperataly
print(a)
# Out:
# [10, 20, 30, 40, 1, 2, 3, 4]

# %%
a.extend('hello') 
print(a)
# Out:
# [10, 20, 30, 40, 1, 2, 3, 4, 'h', 'e', 'l', 'l', 'o']

# %%
a.extend(['hi','hey'])
print(a)
# Out:
# [10, 20, 30, 40, 1, 2, 3, 4, 'h', 'e', 'l', 'l', 'o', 'hi', 'hey']

# %%
a.remove('hey')
print(a)
# Out:
# [10, 20, 30, 40, 1, 2, 3, 4, 'h', 'e', 'l', 'l', 'o']

# %%
b = [10,2,30,40,50,60]
b.insert(1,20)
print(b)
# Out:
# [10, 20, 2, 30, 40, 50, 60]

# %%
b.remove(2)

# %%
b
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
b[5] = 600
b
# Out:
# [10, 20, 30, 40, 50, 600]

# %%
b.insert(4,70)
b
# Out:
# [10, 20, 30, 40, 70, 50, 600, 70]

# %%
b.remove(70)

# %%
b
# Out:
# [10, 20, 30, 40, 50, 600, 70]

# %%
x = [1,1,1,2,2,2,2,2,3,3,33,4,5]
x.count(2)
# Out:
# 5

# %%
x.count(33)
# Out:
# 1

# %%
x.pop() # it remove the last element and return element which pop() remove.
# Out:
# 5

# %%
x.pop()
# Out:
# 4

# %%
x.pop(3) # it remove the 3rd index element.
# Out:
# 2

# %%
x
# Out:
# [1, 1, 1, 2, 2, 2, 2, 3, 3, 33]

# %%
x.reverse()
print(x)
# Out:
# [33, 3, 3, 2, 2, 2, 2, 1, 1, 1]

# %%
x.sort()
x
# Out:
# [1, 1, 1, 2, 2, 2, 2, 3, 3, 33]

# %%
x_c = x
x_c
# Out:
# [1, 1, 1, 2, 2, 2, 2, 3, 3, 33]

# %%
x.insert(4,50)
x
# Out:
# [1, 1, 1, 2, 50, 2, 2, 2, 3, 3, 33]

# %%
x_c
# Out:
# [1, 1, 1, 2, 50, 2, 2, 2, 3, 3, 33]

# %%
x_C = x.copy()
x_C
# Out:
# [1, 1, 1, 2, 50, 2, 2, 2, 3, 3, 33]

# %%
x.pop()
# Out:
# 33

# %%
x_C
# Out:
# [1, 1, 1, 2, 50, 2, 2, 2, 3, 3, 33]

# %%
x
# Out:
# [1, 1, 1, 2, 50, 2, 2, 2, 3, 3]
