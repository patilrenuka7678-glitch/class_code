# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
x = [1,2,6,5,4]
y = [20,27,48,49,16]

# %%
sns.lineplot(x = x, y = y,color = 'red')
# Out:
# <Axes: >

# %%
sns.barplot(x=x,y= y,color = 'pink')
# Out:
# <Axes: >

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(data = df, x = 'total_bill', y = 'tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data = df, x = 'total_bill',y = 'tip',hue = 'smoker')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data = df, x = 'total_bill', y = 'tip',hue = 'day')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data = df, x = 'total_bill', y = 'tip', style = 'time',hue = 'day')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data = df, x = 'total_bill', y = 'tip', style = 'size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data = df, x = 'total_bill', y = 'tip', style = 'size',hue = 'day')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
data = sns.load_dataset('taxis')

# %%
data
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
sns.scatterplot(data = data, x = 'distance', y = 'fare')
# Out:
# <Axes: xlabel='distance', ylabel='fare'>

# %%
sns.countplot(data = data, x = 'payment')
# Out:
# <Axes: xlabel='payment', ylabel='count'>

# %%
sns.scatterplot(data = data, x = 'fare', y = 'tip', hue = 'total',palette='coolwarm')
# Out:
# <Axes: xlabel='fare', ylabel='tip'>

# %%
sns.countplot(data = data, x = 'pickup_borough',color = 'red')
# Out:
# <Axes: xlabel='pickup_borough', ylabel='count'>

# %%
sns.countplot(data = data,x = 'dropoff_borough')
# Out:
# <Axes: xlabel='dropoff_borough', ylabel='count'>

# %%
sns.countplot(data = data,x = 'passengers')
# Out:
# <Axes: xlabel='passengers', ylabel='count'>

# %%
sns.countplot(data = data, x = 'color',color = 'lightblue')
# Out:
# <Axes: xlabel='color', ylabel='count'>
