# %% [markdown]
# # Data Type
# 02/07/2026

# %% [raw]
# Type 1 : Int
# ex. Total no of Members in Family
# outout : 4

# %%
#function to check the Data type.........
type(4)
# Out:
# int

# %% [raw]
# Type 2 : Float
# ex. Student weight
# output : 56.5

# %%
type(56.5)
# Out:
# float

# %% [raw]
# type 3 : String (str)
# ex. Words, Sentences
# instruction : use '', " " (For single Line)
# Multiple Lines or sentences : Use ''' ''', """ """

# %%
type("""This is String""")
# Out:
# str

# %%
print("""This is 1st string
This is 2nd string
this is 3rd string""")
# Out:
# This is 1st string
# This is 2nd string
# this is 3rd string

# %%
#this is difference between the use print or without print.....
("""This is 1st string
This is 2nd string
this is 3rd string""")
# Out:
# 'This is 1st string\nThis is 2nd string\nthis is 3rd string'

# %%
a = 10
b = 20
print(a + b)
# Out:
# 30

# %%
a = 'Renuka'
b = 'Renuka'
if(a == b):
    print("a and b is equal")
else:
    print("both are not equal")
# Out:
# a and b is equal

# %% [markdown]
# # Variable
# 03/05/2026

# %%
# variable must have characters..
# varible not contain the special characters and numbers...
# variable name not contain the Function name (like: type())
a = 5
a
# Out:
# 5

# %%
type(a)
# Out:
# int

# %%
del type

# %%
type(a)
# Out:
# int

# %% [markdown]
# # Typecasting
# Change One datatype into another type...

# %%
# we can convert int into the string ......
str(a)
# Out:
# '5'

# %%
# here we can convert string into the int when string contain only number's..
# but we can not convert the string into the int.....
int(a)
# Out:
# 5

# %%
a = 5
float(a) # convert int value into the float value...
# Out:
# 5.0

# %%
b = 20.30
int(b) # convert float value into the int value...
# Out:
# 20

# %%
c = 30
bool(c)
# Out:
# True

# %% [markdown]
# # Oprators
# 06/07/2026

# %% [raw]
# Arithmetic Operators
# + : Addition
# - : Subtraction
# * : Multiplication
# / : Division
# ** : power of any no
# // : to get the exact value (constant value of the division without any decimal)
# % : reminder

# %%
a = 14
b = 2
print(a + b)
print(a - b)
print(a * b)
print(a / b)
# Out:
# 16
# 12
# 28
# 7.0

# %%
a = 5
b = 2
print (a ** b) # here 2 * 2 * 2 just because of 2 have power 3......
print (a // b) # here 5 / 2 and answer will be 2.5 just because of using the '//' we get the contant value not get decimal value...
print (a % b) # % gives use the reminader....
# Out:
# 25
# 2
# 1

# %% [markdown]
# # Assignment operator

# %%
a = 5
a += 1 # here a = 5 already after a += 1 it uasually a = a + 1 means a = 5 + 1....
a
# Out:
# 6

# %%
b = 10
b -= 2
b # here b = 10 after assign b -= 2 uasually b = b - 2....
# This is same for all arithmetic operators
# Out:
# 8

# %%
c = 2
c **= 3
c
# Out:
# 8

# %%
c = 30
c //= 4 # here c = c // 4 means c = 30 // 4 means it's answer is 7.5 but '//' it shows only the constant values...
c
# Out:
# 7

# %%
d = 30
d %= 4 # during division we get 2 as reminder after 4 * 7 is 28 minus from 30.....
d
# Out:
# 2

# %% [markdown]
# # Relational(comparision) Operator
# 08/07/2026

# %%
a = 5 # single equals to means assign a value to the variable...
a == 5 # double equals to means comparison..
# Out:
# True

# %%
6 != 7
# Out:
# True

# %%
10 > 5
# Out:
# True

# %%
10 < 5
# Out:
# False

# %%
5 >= 5  # 1st it's check 5 > 5 if condition not statifiy so it check 5 = 5 ....
# Out:
# True

# %%
6 <= 6
# Out:
# True

# %% [markdown]
# # Logical Operator

# %% [raw]
# And :- Return true if both condition are true..

# %%
10 > 5 and 5 > 2
# Out:
# True

# %%
10 < 5 and 5 > 2 # it's return false because 1st condition is not true...
# Out:
# False

# %% [raw]
# Or :- Return true if atleast one condition are true..

# %%
10 < 5 or 5 > 2
# Out:
# True

# %%
10 > 5 or 5 > 2
# Out:
# True

# %%
'hello' == 'holl' or 'hi' == 'hey' # here it's return the false becouse of the both conditions are false..
# Out:
# False

# %% [raw]
# Not :- Return reverse result means True to False..

# %%
not(5 == 5)
# Out:
# False

# %%
not(5 == 7)
# Out:
# True

# %% [raw]
# print statements : which is use to print the data or take input or data from the user..
#
# f :- to print the value of variable inside the print statement..

# %%
age = 20
print('My age is',age)
# Out:
# My age is 20

# %%
name = 'Renuka'
print(f'My name is {name} and my age is {age}')
# Out:
# My name is Renuka and my age is 20

# %%
name = input('Enter your name:')
print(name)
# Out:
# Enter your name: Renuka
# Renuka

# %%
type(name)
# Out:
# str

# %%
marks = int(input('Enter your marks:'))
print(marks)
# Out:
# Enter your marks: 90
# 90

# %%
type(marks)
# Out:
# int

# %%
weight = float(input('Enter your weight:'))
print(weight)
# Out:
# Enter your weight: 90.87
# 90.87

# %% [markdown]
# # Data Structure

# %% [raw]
# List :- It's set of which allow duplicate, mutable and ordered..
# List is repesent the data in the Square Bracket '[]' ..
# Any type of data store in this list...
#
# Index is the placevalue of the data in the list....
# l = [10,20,30]
# 10 --> 0
# 20 --> 1
# 30 --> 2
#
# here index start with 0.

# %%
l = [10,20,30,40,50,60]
print(l)
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
l1 = ['hello', 20, 5 + 8j, True, 20.38]
print(l1)
# Out:
# ['hello', 20, (5+8j), True, 20.38]

# %%
# Methods..

l[5]
# Out:
# 60

# %%
# slice[start index : end index]

# slice[start index : end index : jump size]

l[1 : 3]
# Out:
# [20, 30]
