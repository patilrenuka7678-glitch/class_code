# %%
f = open('1st.txt',mode = 'w')

# %%
f.write('Hello! I am renuka.')
# Out:
# 19

# %%
f.close()

# %%
f = open('1st.txt',mode = 'r')

# %%
f.read()
# Out:
# 'Hello! I am renuka.'

# %%
f.read()   # when we again run the read() so it give us empty because the cursor is at the end...
# Out:
# ''

# %%
f.seek(0)   # seek() is used for move the cursor...
# Out:
# 0

# %%
f.read()
# Out:
# 'Hello! I am renuka.'

# %%
f = open('1st.txt',mode = 'r+')

# %%
f.write('How are you ? may your are fine')
# Out:
# 31

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# 'How are you ? may your are fine'

# %%
f.seek(0)
# Out:
# 0

# %%
f.write('renuka')
# Out:
# 6

# %%
f.read()
# Out:
# 'e you ? may your are fine'

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# 'renukae you ? may your are fine'

# %%
f.read()
# Out:
# 're fine'

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# 'renuka how are you ? may your are fine'

# %%
f.close()

# %%
f = open('2nd.txt',mode = 'w')

# %%
f.write("""This is my 1st sentence
This is my 2nd sentence
This is my 3rd sentence""")
# Out:
# 71

# %%
f = open('2nd.txt',mode = 'r')

# %%
f.read()
# Out:
# 'This is my 1st sentence\nThis is my 2nd sentence\nThis is my 3rd sentence'

# %%
f.seek(0)
# Out:
# 0

# %%
f.readline()
# Out:
# 'This is my 1st sentence\n'

# %%
f.readline()
# Out:
# 'This is my 2nd sentence\n'

# %%
f.readline()
# Out:
# 'This is my 3rd sentence'

# %%
f.readline()
# Out:
# ''

# %%
f.seek(0)
# Out:
# 0

# %%
f.readlines()
# Out:
# ['This is my 1st sentence\n',
#  'This is my 2nd sentence\n',
#  'This is my 3rd sentence']

# %%
'this is example of slite'.split(' ')
# Out:
# ['this', 'is', 'example', 'of', 'slite']

# %%
f.seek(0)
# Out:
# 0

# %%
for i in f.readlines():
    print(i)
# Out:
# This is my 1st sentence
#
# This is my 2nd sentence
#
# This is my 3rd sentence

# %%
f.close()

# %%
f = open('2nd.txt', mode = 'w')

# %%
f.write('hello this is write mode.')
# Out:
# 25

# %%
f = open('2nd.txt', mode = 'r')

# %%
f.read()
# Out:
# 'hello this is write mode.'

# %%
f = open('2nd.txt',mode = 'a')

# %%
f.write('\n This is 2nd sentence')
# Out:
# 22

# %%
f = open('2nd.txt',mode = 'r')

# %%
f.read()
# Out:
# 'hello this is write mode.\n This is 2nd sentence'

# %%
f.seek(0)
# Out:
# 0

# %%
f.readline()
# Out:
# 'hello this is write mode.\n'

# %%
f.readline()
# Out:
# ' This is 2nd sentence'

# %%
f = open('myfile.py', mode = 'w')

# %%
f.write("""# This is myfile created by file handling
def square(n):
    return n * n
def even_odd(n):
    if n % 2 == 0:
        return 'Even no',n
    else:
        return 'Odd no',n """)
# Out:
# 173

# %%
f = open('myfile.py',mode = 'r')

# %%
f.read()
# Out:
# "# This is myfile created by file handling\ndef square(n):\n    return n * n\ndef even_odd(n):\n    if n % 2 == 0:\n        return 'Even no',n\n    else:\n        return 'Odd no',n # This is myfile created by file handling\ndef square(n):\n    return n * n\ndef even_odd(n):\n    if n % 2 == 0:\n        return 'Even no',n\n    else:\n        return 'Odd no',n "

# %%
f = open('para.txt',mode = 'w+')

# %%
f.write("""The best university The best university in India is the Indian Institute of Science, ranked 201–250 in the world according 
to the Times Higher Education World University Rankings 2025. It stands out for its exceptional teaching and research environment, 
as well as its strong industry score of 97.3, indicating its ability to drive innovation and collaborate with businesses through research, 
consultancy, and technology transfer.""")
# Out:
# 433

# %%
f.seek(0)
# Out:
# 0

# %%
text = f.read()
data = text.split(' ')

for word in data:
    print(word,data.count(word))
# Out:
# The 2
# best 2
# university 2
# The 2
# best 2
# university 2
# in 2
# India 1
# is 1
# the 3
# Indian 1
# Institute 1
# of 2
# Science, 1
# ranked 1
# 201–250 1
# in 2
# the 3
# world 1
# according 1
#
# to 1
# the 3
# Times 1
# Higher 1
# Education 1
# World 1
# University 1
# Rankings 1
# 2025. 1
# It 1
# stands 1
# out 1
# for 1
# its 3
# exceptional 1
# teaching 1
# and 3
# research 1
# environment, 1
#
# as 1
# well 1
# as 1
# its 3
# strong 1
# industry 1
# score 1
# of 2
# 97.3, 1
# indicating 1
# its 3
# ability 1
# to 1
# drive 1
# innovation 1
# and 3
# collaborate 1
# with 1
# businesses 1
# through 1
# research, 1
#
# consultancy, 1
# and 3
# technology 1
# transfer. 1

# %%
f.seek(0)
# Out:
# 0

# %%
text = f.read()
data = text.split(' ')

for word in set(data):
    print(word,data.count(word))
# Out:
# Times 1
# World 1
#
# to 1
# with 1
# ability 1
# strong 1
# 97.3, 1
# through 1
# exceptional 1
# industry 1
# It 1
# businesses 1
# stands 1
# innovation 1
# University 1
# and 3
# best 2
# the 3
# of 2
# according 1
# its 3
# for 1
# research 1
# 201–250 1
# Indian 1
# to 1
# Institute 1
# well 1
# environment, 1
# ranked 1
#
# consultancy, 1
# university 2
# The 2
# research, 1
# transfer. 1
# world 1
# Education 1
# out 1
# as 1
# technology 1
# Rankings 1
# Science, 1
# teaching 1
# score 1
# in 2
# 2025. 1
# drive 1
# is 1
#
# as 1
# collaborate 1
# India 1
# indicating 1
# Higher 1
