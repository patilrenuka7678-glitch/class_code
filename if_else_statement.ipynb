# %%
if 10 > 5:
    print(True)
else:
    print(False)
# Out:
# True

# %%
marks = float(input('Enter Your marks:'))

if marks >= 35:
    print('pass')
else:
    print('fail')
# Out:
# Enter Your marks: 35
# pass

# %%
marks = float(input('Enter your Marks:'))

if marks >= 90 and marks <= 100:
    print('Exellent')
elif marks >= 80 and marks < 90:
    print('very Good')
elif marks >= 70 and marks < 80:
    print('good Job')
elif marks >= 60 and marks < 70:
    print('Good')
elif marks >= 35 and marks < 60:
    print('Pass')
elif marks >=0 and marks < 35:
    print('Fail')
else:
    print('Enter Valid Marks!')
# Out:
# Enter your Marks: 91
# Exellent

# %%
course = input('Enter Your Course Name:')
fees = float(input('Enter Your Fess:'))

if course == 'Data Science':
    discount = fees * 0.4
    print(f'You Will get {discount} % Discount')
    print(f'Your total Fees is {fees - discount}')
elif course == 'python':
    discount = fees * 0.3
    print(f'You will get {dicount} % Discount')
    print(f'Your total fees id {fees - discount}')
elif course == 'java':
    discount = fees * 0.1
    print(f'you will get {discount} % Discount')
    print(f'your total fees is {fees - discount}')
else:
    print('Please Enter The valid course name')
# Out:
# Enter Your Course Name: java
# Enter Your Fess: 34500
# you will get 3450.0 % Discount
# your total fees is 31050.0
