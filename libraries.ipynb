# %%
import numpy as np

# %%
a = [10,28,39,30,38]
np.mean(a)
# Out:
# np.float64(29.0)

# %%
d1 = np.array([1,2,3,4,5])

# %%
d1
# Out:
# array([1, 2, 3, 4, 5])

# %%
d1.ndim
# Out:
# 1

# %%
d2 = np.array([[1,2,3,4,5],[10,20,30,40,50]])

# %%
d2
# Out:
# array([[ 1,  2,  3,  4,  5],
#        [10, 20, 30, 40, 50]])

# %%
d2.ndim
# Out:
# 2

# %%
d3 = np.array([[[1,2,3],[10,20,30],[0.1,0.2,0.3]]])

# %%
d3
# Out:
# array([[[ 1. ,  2. ,  3. ],
#         [10. , 20. , 30. ],
#         [ 0.1,  0.2,  0.3]]])

# %%
d3.ndim
# Out:
# 3

# %%
np.random.random_integers(1,10,5)
# Out:
# C:\Users\renuka\AppData\Local\Temp\ipykernel_13644\3200928123.py:1: DeprecationWarning: This function is deprecated. Please call randint(1, 10 + 1) instead
#   np.random.random_integers(1,10,5)
# array([2, 3, 1, 2, 8], dtype=int32)

# %%
np.std([10,20,30,45,64])
# Out:
# np.float64(19.019989484749985)

# %%
np.var([10,20,30,45,64])
# Out:
# np.float64(361.76)

# %%
np.median([10,20,30,45,64])
# Out:
# np.float64(30.0)

# %%
import statistics

# %%
data = [10,20,36,73,89,20,10,10,2,10]
statistics.mode(data)
# Out:
# 10
