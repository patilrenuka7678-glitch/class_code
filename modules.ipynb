# %% [markdown]
# # Modules

# %% [raw]
# modules are simple file containing python code with '.py' Extension which is a reusable code.

# %%
import functions_file as f

# %%
f.square(2)
# Out:
# 4

# %%
f.square(10)
# Out:
# 100

# %%
import multiple_mod as m

# %%
m.addition(39,45)
# Out:
# 84

# %%
m.division(18,3)
# Out:
#  you 18 and 3 as input which result is 6.0

# %%
m.division(90,0)
# Out:
# error occurred here division by zero

# %%
m.square(30)
# Out:
# 900
